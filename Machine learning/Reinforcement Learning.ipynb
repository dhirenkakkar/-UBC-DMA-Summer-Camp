# %%
import gym
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
import numpy as np
import itertools

env = gym.make('FrozenLake-v0')
print(env.observation_space)
print(env.action_space)
env.reset()  # this is what will reset the environment to the starting state––always use this first.

x = 0
y = 0

winpos = []
winmoves = []

while x < 10:
    env.reset()

    moves = []
    pos = []
    prevobs = 0
    while True:

        y = env.action_space.sample()
        obs, rew, done, info = env.step(y)
        moves.append(y)
        pos.append([prevobs])
        prevobs = obs
        # obs, rew, done, info = env.step(env.action_space.sample()) # take an action
        env.render()

        if rew > 0:
            winpos.extend(pos)
            winmoves.extend(moves)

        print(rew)
        if done:
            x = (rew + x)
            print(x)
            print(y)
            # print(moves)
            # print(pos)
            print("Winning moves: ", winmoves)
            print("Winning positions: ", winpos)
            print("Previous Observation: ", prevobs)
            break
LR = 0.001


# now that we've created data, let's create our neural net
# this will take an parameter of input_size, to make it useful for other environments
# but this will end up being 4 (our observations)
def neural_net_model(input_size):
    # to avoid awkward imports, we're going to just use the tf prefix for all
    # there's a little bit more going on here than in our titanic example, so let's take it slow

    # the first layer is our input layer
    # we have to tell it the shape of our data,
    # that's always [None, the number of inputs, other input layers, more layer, etc]
    # here we have a shape of 4 input (the observation) by 1 (one observation each time)
    # in this case, input_size, will be 4, but by using a variable, we could do other shapes
    #network = tf.input_data(shape=[None, input_size], name='input')
    network = Sequential()
    network.add(Dense(output_dim=input_size, activation='relu'))

    # a hidden layer with 128 nodes, using regular linear regression (this is default)
    #network = tf.fully_connected(network, 128, activation='relu')
    network.add(Dense(output_dim=128, activation='relu'))
    # so dropout is a bit weird. basically, to prevent overfitting (over analyzing the problem),
    # we'll randomly drop part of the network. We do this to attempt to get a more organic,
    # less strict network that won't create rules that are too harsh.
    # more info: https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
    # we could experiment with this, I think
    #network = tf.dropout(network, 0.8)
    network.add(Dropout(0.2))

    # alright lets make a bunch more layers, keeping it symmetrical
    #network = tf.fully_connected(network, 256, activation='relu', name="hlayer1")
    #network = tf.dropout(network, 0.8)
    network.add(Dense(output_dim=256, activation='relu'))
    network.add(Dropout(0.2))

    #network = tf.fully_connected(network, 512, activation='relu', name="hlayer2")
    #network = tf.dropout(network, 0.8)
    network.add(Dense(output_dim=512, activation='relu'))
    network.add(Dropout(0.2))

    #network = tf.fully_connected(network, 256, activation='relu', name="hlayer3")
    #network = tf.dropout(network, 0.8)
    network.add(Dense(output_dim=256, activation='relu'))
    network.add(Dropout(0.2))

    #network = tf.fully_connected(network, 128, activation='relu', name="hlayer4")
    #network = tf.dropout(network, 0.8)
    network.add(Dense(output_dim=128, activation='relu'))
    network.add(Dropout(0.2))

    # this is our output layer.
    # it contains an array like [l, r], probabilities for each lef or right
    # if you're curious about activations:
    # https://github.com/Kulbear/deep-learning-nano-foundation/wiki/ReLU-and-Softmax-Activation-Functions
    # essentially the softmax activation will squash our outputs into a probability distrubution
    #network = tf.fully_connected(network, 4, activation='softmax', name="out")
    #network = tf.regression(network, learning_rate=LR)
    network.add(Dense(output_dim=4, activation='softmax'))
    network.compile(loss ='mean_squared_error', optimizer=Adam(lr=0.001), metrics =['accuracy'])

    # make a Deep Neaural Net wtih with network
    #model = tf.DNN(network, tensorboard_dir='log')

    return network


def train_model(moves, pos):
    # this is the awkard part, we need to organize that data a bit better,
    # in order to actually feed it to the net

    #pos = list(itertools.chain.from_iterable(pos))
    pos = map(np.array, pos)
    
    model = neural_net_model(input_size=1)
    #model.fit(pos, moves, n_epoch=5, show_metric=True, run_id='openai_learning')
    model.fit(pos, moves, batch_size = 512, nb_epoch = 5, verbose = 1)
    return model


def play_with_model(model):
    scores = 0
    choices = []
    print("Playing wtih Trained Model.....")
    for each_game in range(10):
        score = 0
        game_memory = []
        prev_obs = 0
        env.reset()
        for _ in range(100):
            #env.render()

            if prev_obs == 0:
                action = env.action_space.sample()
            else:
                # this clever call finds the index of the max argument
                # since predict will return something like [][0.23.., 0.76..]]
                # it will return 0 if the first is bigger, 1 if the second
                # which is the same as 'left' or 'right' in the action space
                action = np.argmax(model.predict([[prev_obs]])[0])

            choices.append(action)

            new_observation, reward, done, info = env.step(action)
            prev_obs = new_observation
            game_memory.append([new_observation, action])
            score += reward
            if done: break

        scores += score

    print(scores)


onehot = []
for m in winmoves:
    onehot.append([0, 0, 0, 0])
    onehot[len(onehot) - 1][m] = 1
model = train_model(onehot, winpos)
play_with_model(model)
# Out:
# Discrete(16)
# Discrete(4)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  7
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  11
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  7
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  7
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  7
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  7
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 0
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 2
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 1
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 0.0
# 3
# Winning moves:  []
# Winning positions:  []
# Previous Observation:  11
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 1.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  15
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  11
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  7
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 1.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ...
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 3
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 8.0
# 0
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 1.0
# 9.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1, 3, 2, 0, 2, 1, 2, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14], [0], [0], [1], [1], [2], [6], [10], [14]]
# Previous Observation:  15
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 9.0
# 2
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1, 3, 2, 0, 2, 1, 2, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14], [0], [0], [1], [1], [2], [6], [10], [14]]
# Previous Observation:  5
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
# 9.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1, 3, 2, 0, 2, 1, 2, 2, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14], [0], [0], [1], [1], [2], [6], [10], [14]]
# Previous Observation:  5
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 1.0
# 10.0
# 1
# Winning moves:  [2, 2, 0, 0, 0, 2, 2, 3, 2, 1, 3, 0, 2, 2, 1, 1, 2, 0, 1, 1, 3, 1, 2, 1, 2, 1, 2, 3, 1, 1, 1, 0, 2, 0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 1, 3, 3, 0, 3, 3, 2, 1, 0, 0, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2, 1, 1, 0, 1, 2, 1, 3, 1, 3, 3, 2, 2, 2, 1, 0, 2, 2, 1, 2, 1, 3, 2, 0, 2, 1, 2, 2, 1, 0, 0, 0, 3, 2, 2, 1, 0, 1]
# Winning positions:  [[0], [4], [8], [8], [4], [8], [9], [13], [14], [14], [14], [0], [0], [0], [1], [2], [6], [10], [14], [13], [14], [0], [4], [8], [9], [10], [14], [14], [0], [4], [4], [4], [8], [9], [13], [14], [14], [13], [13], [14], [0], [1], [1], [2], [6], [2], [1], [0], [1], [2], [2], [6], [10], [14], [0], [0], [4], [8], [9], [10], [14], [0], [0], [0], [0], [4], [8], [9], [10], [14], [14], [14], [14], [0], [4], [0], [0], [4], [8], [9], [10], [14], [10], [14], [13], [14], [0], [0], [1], [1], [2], [6], [10], [14], [0], [4], [8], [8], [8], [9], [13], [14], [14]]
# Previous Observation:  15
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:69: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=1)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:73: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:85: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=256)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:90: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=512)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:95: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=256)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:110: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="softmax", units=4)`
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:128: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f75f0585c05e> in <module>
#     168     onehot.append([0, 0, 0, 0])
#     169     onehot[len(onehot) - 1][m] = 1
# --> 170 model = train_model(onehot, winpos)
#     171 play_with_model(model)
#
# <ipython-input-15-f75f0585c05e> in train_model(moves, pos)
#     126     model = neural_net_model(input_size=1)
#     127     #model.fit(pos, moves, n_epoch=5, show_metric=True, run_id='openai_learning')
# --> 128     model.fit(pos, moves, batch_size = 512, nb_epoch = 5, verbose = 1)
#     129     return model
#     130
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     668                                      'either a single '
#     669                                      'array or a list of arrays. '
# --> 670                                      'You passed: x=' + str(x))
#     671                 all_inputs.append(x)
#     672
#
# ValueError: Please provide as model inputs either a single array or a list of arrays. You passed: x=<map object at 0x10e0ae9b0>
